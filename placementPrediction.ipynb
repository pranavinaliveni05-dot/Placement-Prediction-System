# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavinaliveni05-dot/Placement-Prediction-System/blob/main/placementPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load the csv file
df = pd.read_csv('placement_data.csv')
# show first 5 rows
print(df.head())
#show data info
print(df.info())
# Out:
#    CGPA  Internships  Projects  AptitudeScore  SoftSkillsRating  Placed
# 0  7.19            3         4             45                 1       1
# 1  9.78            3         3             99                 5       1
# 2  8.79            2         2             70                 5       1
# 3  8.19            0         3             58                 2       1
# 4  6.20            3         4             83                 3       1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CGPA              200 non-null    float64
#  1   Internships       200 non-null    int64
#  2   Projects          200 non-null    int64
#  3   AptitudeScore     200 non-null    int64
#  4   SoftSkillsRating  200 non-null    int64
#  5   Placed            200 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 9.5 KB
# None
